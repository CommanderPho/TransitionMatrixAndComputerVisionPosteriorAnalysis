% %% [markdown]
% # <span style="color:rgb(213,80,0)">\# 2024\-08\-20 \- Computer Vision (CV) Posterior Analyses </span>

% %%
addpath(genpath('helpers'));
addpath('External'); % Not recur

should_use_parallel = true;
%should_use_parallel = false;

%img_path = fullfile("E:\Dropbox (Personal)\Active\Kamran Diba Lab\Pho-Kamran-Meetings\2024-08-20 - Finalizing Transition Matrix_temp_individual_posteriors\2024-08-28\laps\long_LR\greyscale");
%img_path = fullfile("E:\Dropbox (Personal)\Active\Kamran Diba Lab\Pho-Kamran-Meetings\2024-08-20 - Finalizing Transition Matrix_temp_individual_posteriors\2024-08-27\laps\greyscale"); % old-style
%img_path = fullfile("E:\Dropbox (Personal)\Active\Kamran Diba Lab\Pho-Kamran-Meetings\2024-08-20 - Finalizing Transition Matrix_temp_individual_posteriors\2024-08-27\ripple\greyscale"); % old-style ripples

% Lab Path:
% '/home/halechr/FastData/_temp_individual_posteriors/2024-08-28/ripple/long_LR/greyscale'
img_path = fullfile("/home/halechr/FastData/_temp_individual_posteriors/2024-08-28/ripple/long_LR/greyscale"); % old-style ripples

%img_path = fullfile("/home/halechr/Desktop/_temp_individual_posteriors/2024-08-21/laps/greyscale");
img_path
% Out:
%             Error: MATLAB Kernel for Jupyter was unable to find the notebook server from which it was spawned!
%
%             Resolution: Please relaunch kernel from JupyterLab or Classic Jupyter Notebook.

% %%
imdsTrain = imageDatastore(img_path,'IncludeSubfolders',false);
imdsTrain.readall("UseParallel", should_use_parallel)
% Out:
% Starting parallel pool (parpool) using the 'Threads' profile ...
% Connected to parallel pool with 8 workers.
% $\begin{array} {|c|c|}\hline\text{ } & \text{1} \\ \hline\text{1} & \text{1024x215 uint8} \\ \hline\text{2} & \text{1024x197 uint8} \\ \hline\text{3} & \text{1024x71 uint8} \\ \hline\text{4} & \text{1024x35 uint8} \\ \hline\text{5} & \text{1024x233 uint8} \\ \hline\text{6} & \text{1024x53 uint8} \\ \hline\text{7} & \text{1024x233 uint8} \\ \hline\text{8} & \text{1024x341 uint8} \\ \hline\text{9} & \text{1024x161 uint8} \\ \hline\text{10} & \text{1024x215 uint8} \\ \hline\text{11} & \text{1024x161 uint8} \\ \hline\text{12} & \text{1024x17 uint8} \\ \hline\text{13} & \text{1024x305 uint8} \\ \hline\text{14} & \text{1024x71 uint8} \\ \hline\end{array}$

% %%
%processed_images = batchposterior_batch_import_imfcn(imdsTrain);
%

% %%
imageBatchProcessor(imdsTrain) % shows the GUI

% %%
processed_images = batchposterior_batch_import_imfcn(imdsTrain);
% Out:
% ipple\greyscale\p_x_given_n[0].png
% ipple\greyscale\p_x_given_n[100].png
% ipple\greyscale\p_x_given_n[101].png
% ipple\greyscale\p_x_given_n[102].png
% ipple\greyscale\p_x_given_n[103].png
% ipple\greyscale\p_x_given_n[104].png
% ipple\greyscale\p_x_given_n[105].png
% ipple\greyscale\p_x_given_n[106].png
% ipple\greyscale\p_x_given_n[107].png
% ipple\greyscale\p_x_given_n[108].png
% ipple\greyscale\p_x_given_n[109].png
% ipple\greyscale\p_x_given_n[10].png
% ipple\greyscale\p_x_given_n[110].png
% ipple\greyscale\p_x_given_n[111].png
% ipple\greyscale\p_x_given_n[112].png
% ipple\greyscale\p_x_given_n[113].png
% ipple\greyscale\p_x_given_n[114].png
% ipple\greyscale\p_x_given_n[115].png
% ipple\greyscale\p_x_given_n[116].png
% ipple\greyscale\p_x_given_n[117].png
% ipple\greyscale\p_x_given_n[118].png
% ipple\greyscale\p_x_given_n[119].png
% ipple\greyscale\p_x_given_n[11].png
% ipple\greyscale\p_x_given_n[120].png
% ipple\greyscale\p_x_given_n[121].png
% ipple\greyscale\p_x_given_n[122].png
% ipple\greyscale\p_x_given_n[123].png
% ipple\greyscale\p_x_given_n[124].png
% ipple\greyscale\p_x_given_n[125].png
% ipple\greyscale\p_x_given_n[126].png
% ipple\greyscale\p_x_given_n[127].png
% ipple\greyscale\p_x_given_n[128].png
% ipple\greyscale\p_x_given_n[129].png
% ipple\greyscale\p_x_given_n[12].png
% ipple\greyscale\p_x_given_n[130].png
% ipple\greyscale\p_x_given_n[131].png
% ipple\greyscale\p_x_given_n[132].png
% ipple\greyscale\p_x_given_n[133].png
% ipple\greyscale\p_x_given_n[134].png
% ipple\greyscale\p_x_given_n[135].png
% ipple\greyscale\p_x_given_n[136].png
% ipple\greyscale\p_x_given_n[137].png
% ipple\greyscale\p_x_given_n[138].png
% ipple\greyscale\p_x_given_n[139].png
% ipple\greyscale\p_x_given_n[13].png
% ipple\greyscale\p_x_given_n[140].png
% ipple\greyscale\p_x_given_n[141].png
% ipple\greyscale\p_x_given_n[142].png
% ipple\greyscale\p_x_given_n[143].png
% ipple\greyscale\p_x_given_n[144].png
% ipple\greyscale\p_x_given_n[145].png
% ipple\greyscale\p_x_given_n[146].png
% ipple\greyscale\p_x_given_n[147].png
% ipple\greyscale\p_x_given_n[148].png
% ipple\greyscale\p_x_given_n[149].png
% ipple\greyscale\p_x_given_n[14].png
% ipple\greyscale\p_x_given_n[150].png
% ipple\greyscale\p_x_given_n[151].png
% ipple\greyscale\p_x_given_n[152].png
% ipple\greyscale\p_x_given_n[153].png
% ipple\greyscale\p_x_given_n[154].png
% ipple\greyscale\p_x_given_n[155].png
% ipple\greyscale\p_x_given_n[156].png
% ipple\greyscale\p_x_given_n[157].png
% ipple\greyscale\p_x_given_n[158].png
% ipple\greyscale\p_x_given_n[159].png
% ipple\greyscale\p_x_given_n[15].png
% ipple\greyscale\p_x_given_n[160].png
% ipple\greyscale\p_x_given_n[161].png
% ipple\greyscale\p_x_given_n[162].png
% ipple\greyscale\p_x_given_n[163].png
% ipple\greyscale\p_x_given_n[164].png
% ipple\greyscale\p_x_given_n[165].png
% ipple\greyscale\p_x_given_n[166].png
% ipple\greyscale\p_x_given_n[167].png
% ipple\greyscale\p_x_given_n[168].png
% ipple\greyscale\p_x_given_n[169].png
% ipple\greyscale\p_x_given_n[16].png
% ipple\greyscale\p_x_given_n[170].png
% ipple\greyscale\p_x_given_n[171].png
% ipple\greyscale\p_x_given_n[172].png
% ipple\greyscale\p_x_given_n[173].png
% ipple\greyscale\p_x_given_n[174].png
% ipple\greyscale\p_x_given_n[175].png
% ipple\greyscale\p_x_given_n[176].png
% ipple\greyscale\p_x_given_n[177].png
% ipple\greyscale\p_x_given_n[178].png
% ipple\greyscale\p_x_given_n[179].png
% ipple\greyscale\p_x_given_n[17].png
% ipple\greyscale\p_x_given_n[180].png
% ipple\greyscale\p_x_given_n[181].png
% ipple\greyscale\p_x_given_n[182].png
% ipple\greyscale\p_x_given_n[183].png
% ipple\greyscale\p_x_given_n[184].png
% ipple\greyscale\p_x_given_n[185].png
% ipple\greyscale\p_x_given_n[186].png
% ipple\greyscale\p_x_given_n[187].png
% ipple\greyscale\p_x_given_n[188].png
% ipple\greyscale\p_x_given_n[189].png
% ipple\greyscale\p_x_given_n[18].png
% ipple\greyscale\p_x_given_n[190].png
% ipple\greyscale\p_x_given_n[191].png
% ipple\greyscale\p_x_given_n[192].png
% ipple\greyscale\p_x_given_n[193].png
% ipple\greyscale\p_x_given_n[194].png
% ipple\greyscale\p_x_given_n[195].png
% ipple\greyscale\p_x_given_n[196].png
% ipple\greyscale\p_x_given_n[197].png
% ipple\greyscale\p_x_given_n[198].png
% ipple\greyscale\p_x_given_n[199].png
% ipple\greyscale\p_x_given_n[19].png
% ipple\greyscale\p_x_given_n[1].png
% ipple\greyscale\p_x_given_n[200].png
% ipple\greyscale\p_x_given_n[201].png
% ipple\greyscale\p_x_given_n[202].png
% ipple\greyscale\p_x_given_n[203].png
% ipple\greyscale\p_x_given_n[204].png
% ipple\greyscale\p_x_given_n[205].png
% ipple\greyscale\p_x_given_n[206].png
% ipple\greyscale\p_x_given_n[207].png
% ipple\greyscale\p_x_given_n[208].png
% ipple\greyscale\p_x_given_n[209].png
% ipple\greyscale\p_x_given_n[20].png
% ipple\greyscale\p_x_given_n[210].png
% ipple\greyscale\p_x_given_n[211].png
% ipple\greyscale\p_x_given_n[212].png
% ipple\greyscale\p_x_given_n[213].png
% ipple\greyscale\p_x_given_n[214].png
% ipple\greyscale\p_x_given_n[215].png
% ipple\greyscale\p_x_given_n[216].png
% ipple\greyscale\p_x_given_n[217].png
% ipple\greyscale\p_x_given_n[218].png
% ipple\greyscale\p_x_given_n[219].png
% ipple\greyscale\p_x_given_n[21].png
% ipple\greyscale\p_x_given_n[220].png
% ipple\greyscale\p_x_given_n[221].png
% ipple\greyscale\p_x_given_n[222].png
% ipple\greyscale\p_x_given_n[223].png
% ipple\greyscale\p_x_given_n[224].png
% ipple\greyscale\p_x_given_n[225].png
% ipple\greyscale\p_x_given_n[226].png
% ipple\greyscale\p_x_given_n[227].png
% ipple\greyscale\p_x_given_n[228].png
% ipple\greyscale\p_x_given_n[229].png
% ipple\greyscale\p_x_given_n[22].png
% ipple\greyscale\p_x_given_n[230].png
% ipple\greyscale\p_x_given_n[231].png
% ipple\greyscale\p_x_given_n[232].png
% ipple\greyscale\p_x_given_n[233].png
% ipple\greyscale\p_x_given_n[234].png
% ipple\greyscale\p_x_given_n[235].png
% ipple\greyscale\p_x_given_n[236].png
% ipple\greyscale\p_x_given_n[237].png
% ipple\greyscale\p_x_given_n[238].png
% ipple\greyscale\p_x_given_n[239].png
% ipple\greyscale\p_x_given_n[23].png
% ipple\greyscale\p_x_given_n[240].png
% ipple\greyscale\p_x_given_n[241].png
% ipple\greyscale\p_x_given_n[242].png
% ipple\greyscale\p_x_given_n[243].png
% ipple\greyscale\p_x_given_n[244].png
% ipple\greyscale\p_x_given_n[245].png
% ipple\greyscale\p_x_given_n[246].png
% ipple\greyscale\p_x_given_n[247].png
% ipple\greyscale\p_x_given_n[248].png
% ipple\greyscale\p_x_given_n[249].png
% ipple\greyscale\p_x_given_n[24].png
% ipple\greyscale\p_x_given_n[250].png
% ipple\greyscale\p_x_given_n[251].png
% ipple\greyscale\p_x_given_n[252].png
% ipple\greyscale\p_x_given_n[253].png
% ipple\greyscale\p_x_given_n[254].png
% ipple\greyscale\p_x_given_n[255].png
% ipple\greyscale\p_x_given_n[256].png
% ipple\greyscale\p_x_given_n[257].png
% ipple\greyscale\p_x_given_n[258].png
% ipple\greyscale\p_x_given_n[259].png
% ipple\greyscale\p_x_given_n[25].png
% ipple\greyscale\p_x_given_n[260].png
% ipple\greyscale\p_x_given_n[261].png
% ipple\greyscale\p_x_given_n[262].png
% ipple\greyscale\p_x_given_n[263].png
% ipple\greyscale\p_x_given_n[264].png
% ipple\greyscale\p_x_given_n[265].png
% ipple\greyscale\p_x_given_n[266].png
% ipple\greyscale\p_x_given_n[267].png
% ipple\greyscale\p_x_given_n[268].png
% ipple\greyscale\p_x_given_n[269].png
% ipple\greyscale\p_x_given_n[26].png
% ipple\greyscale\p_x_given_n[270].png
% ipple\greyscale\p_x_given_n[271].png
% ipple\greyscale\p_x_given_n[272].png
% ipple\greyscale\p_x_given_n[273].png
% ipple\greyscale\p_x_given_n[274].png
% ipple\greyscale\p_x_given_n[275].png
% ipple\greyscale\p_x_given_n[276].png
% ipple\greyscale\p_x_given_n[277].png
% ipple\greyscale\p_x_given_n[278].png
% ipple\greyscale\p_x_given_n[279].png
% ipple\greyscale\p_x_given_n[27].png
% ipple\greyscale\p_x_given_n[280].png
% ipple\greyscale\p_x_given_n[281].png
% ipple\greyscale\p_x_given_n[282].png
% ipple\greyscale\p_x_given_n[283].png
% ipple\greyscale\p_x_given_n[284].png
% ipple\greyscale\p_x_given_n[285].png
% ipple\greyscale\p_x_given_n[286].png
% ipple\greyscale\p_x_given_n[287].png
% ipple\greyscale\p_x_given_n[288].png
% ipple\greyscale\p_x_given_n[289].png
% ipple\greyscale\p_x_given_n[28].png
% ipple\greyscale\p_x_given_n[290].png
% ipple\greyscale\p_x_given_n[291].png
% ipple\greyscale\p_x_given_n[292].png
% ipple\greyscale\p_x_given_n[293].png
% ipple\greyscale\p_x_given_n[294].png
% ipple\greyscale\p_x_given_n[295].png
% ipple\greyscale\p_x_given_n[296].png
% ipple\greyscale\p_x_given_n[297].png
% ipple\greyscale\p_x_given_n[298].png
% ipple\greyscale\p_x_given_n[299].png
% ipple\greyscale\p_x_given_n[29].png
% ipple\greyscale\p_x_given_n[2].png
% ipple\greyscale\p_x_given_n[300].png
% ipple\greyscale\p_x_given_n[301].png
% ipple\greyscale\p_x_given_n[302].png
% ipple\greyscale\p_x_given_n[303].png
% ipple\greyscale\p_x_given_n[304].png
% ipple\greyscale\p_x_given_n[305].png
% ipple\greyscale\p_x_given_n[306].png
% ipple\greyscale\p_x_given_n[307].png
% ipple\greyscale\p_x_given_n[308].png
% ipple\greyscale\p_x_given_n[309].png
% ipple\greyscale\p_x_given_n[30].png
% ipple\greyscale\p_x_given_n[310].png
% ipple\greyscale\p_x_given_n[311].png
% ipple\greyscale\p_x_given_n[312].png
% ipple\greyscale\p_x_given_n[313].png
% ipple\greyscale\p_x_given_n[314].png
% ipple\greyscale\p_x_given_n[315].png
% ipple\greyscale\p_x_given_n[316].png
% ipple\greyscale\p_x_given_n[317].png
% ipple\greyscale\p_x_given_n[318].png
% ipple\greyscale\p_x_given_n[319].png
% ipple\greyscale\p_x_given_n[31].png
% ipple\greyscale\p_x_given_n[320].png
% ipple\greyscale\p_x_given_n[321].png
% ipple\greyscale\p_x_given_n[322].png
% ipple\greyscale\p_x_given_n[323].png
% ipple\greyscale\p_x_given_n[324].png
% ipple\greyscale\p_x_given_n[325].png
% ipple\greyscale\p_x_given_n[326].png
% ipple\greyscale\p_x_given_n[327].png
% ipple\greyscale\p_x_given_n[328].png
% ipple\greyscale\p_x_given_n[329].png
% ipple\greyscale\p_x_given_n[32].png
% ipple\greyscale\p_x_given_n[330].png
% ipple\greyscale\p_x_given_n[331].png
% ipple\greyscale\p_x_given_n[332].png
% ipple\greyscale\p_x_given_n[333].png
% ipple\greyscale\p_x_given_n[334].png
% ipple\greyscale\p_x_given_n[335].png
% ipple\greyscale\p_x_given_n[336].png
% ipple\greyscale\p_x_given_n[337].png
% ipple\greyscale\p_x_given_n[338].png
% ipple\greyscale\p_x_given_n[339].png
% ipple\greyscale\p_x_given_n[33].png
% ipple\greyscale\p_x_given_n[340].png
% ipple\greyscale\p_x_given_n[341].png
% ipple\greyscale\p_x_given_n[342].png
% ipple\greyscale\p_x_given_n[343].png
% ipple\greyscale\p_x_given_n[344].png
% ipple\greyscale\p_x_given_n[345].png
% ipple\greyscale\p_x_given_n[346].png
% ipple\greyscale\p_x_given_n[347].png
% ipple\greyscale\p_x_given_n[348].png
% ipple\greyscale\p_x_given_n[349].png
% ipple\greyscale\p_x_given_n[34].png
% ipple\greyscale\p_x_given_n[350].png
% ipple\greyscale\p_x_given_n[351].png
% ipple\greyscale\p_x_given_n[352].png
% ipple\greyscale\p_x_given_n[353].png
% ipple\greyscale\p_x_given_n[354].png
% ipple\greyscale\p_x_given_n[355].png
% ipple\greyscale\p_x_given_n[356].png
% ipple\greyscale\p_x_given_n[357].png
% ipple\greyscale\p_x_given_n[358].png
% ipple\greyscale\p_x_given_n[359].png
% ipple\greyscale\p_x_given_n[35].png
% ipple\greyscale\p_x_given_n[360].png
% ipple\greyscale\p_x_given_n[361].png
% ipple\greyscale\p_x_given_n[362].png
% ipple\greyscale\p_x_given_n[363].png
% ipple\greyscale\p_x_given_n[364].png
% ipple\greyscale\p_x_given_n[365].png
% ipple\greyscale\p_x_given_n[366].png
% ipple\greyscale\p_x_given_n[367].png
% ipple\greyscale\p_x_given_n[368].png
% ipple\greyscale\p_x_given_n[369].png
% ipple\greyscale\p_x_given_n[36].png
% ipple\greyscale\p_x_given_n[370].png
% ipple\greyscale\p_x_given_n[371].png
% ipple\greyscale\p_x_given_n[372].png
% ipple\greyscale\p_x_given_n[373].png
% ipple\greyscale\p_x_given_n[374].png
% ipple\greyscale\p_x_given_n[375].png
% ipple\greyscale\p_x_given_n[376].png
% ipple\greyscale\p_x_given_n[377].png
% ipple\greyscale\p_x_given_n[378].png
% ipple\greyscale\p_x_given_n[379].png
% ipple\greyscale\p_x_given_n[37].png
% ipple\greyscale\p_x_given_n[380].png
% ipple\greyscale\p_x_given_n[381].png
% ipple\greyscale\p_x_given_n[382].png
% ipple\greyscale\p_x_given_n[383].png
% ipple\greyscale\p_x_given_n[384].png
% ipple\greyscale\p_x_given_n[385].png
% ipple\greyscale\p_x_given_n[386].png
% ipple\greyscale\p_x_given_n[387].png
% ipple\greyscale\p_x_given_n[388].png
% ipple\greyscale\p_x_given_n[389].png
% ipple\greyscale\p_x_given_n[38].png
% ipple\greyscale\p_x_given_n[390].png
% ipple\greyscale\p_x_given_n[391].png
% ipple\greyscale\p_x_given_n[392].png
% ipple\greyscale\p_x_given_n[393].png
% ipple\greyscale\p_x_given_n[394].png
% ipple\greyscale\p_x_given_n[395].png
% ipple\greyscale\p_x_given_n[396].png
% ipple\greyscale\p_x_given_n[397].png
% ipple\greyscale\p_x_given_n[398].png
% ipple\greyscale\p_x_given_n[399].png
% ipple\greyscale\p_x_given_n[39].png
% ipple\greyscale\p_x_given_n[3].png
% ipple\greyscale\p_x_given_n[400].png
% ipple\greyscale\p_x_given_n[401].png
% ipple\greyscale\p_x_given_n[402].png
% ipple\greyscale\p_x_given_n[403].png
% ipple\greyscale\p_x_given_n[404].png
% ipple\greyscale\p_x_given_n[405].png
% ipple\greyscale\p_x_given_n[406].png
% ipple\greyscale\p_x_given_n[407].png
% ipple\greyscale\p_x_given_n[408].png
% ipple\greyscale\p_x_given_n[409].png
% ipple\greyscale\p_x_given_n[40].png
% ipple\greyscale\p_x_given_n[410].png
% ipple\greyscale\p_x_given_n[411].png
% ipple\greyscale\p_x_given_n[412].png
% ipple\greyscale\p_x_given_n[413].png
% ipple\greyscale\p_x_given_n[414].png
% ipple\greyscale\p_x_given_n[415].png
% ipple\greyscale\p_x_given_n[416].png
% ipple\greyscale\p_x_given_n[417].png
% ipple\greyscale\p_x_given_n[418].png
% ipple\greyscale\p_x_given_n[419].png
% ipple\greyscale\p_x_given_n[41].png
% ipple\greyscale\p_x_given_n[420].png
% ipple\greyscale\p_x_given_n[421].png
% ipple\greyscale\p_x_given_n[422].png
% ipple\greyscale\p_x_given_n[423].png
% ipple\greyscale\p_x_given_n[424].png
% ipple\greyscale\p_x_given_n[425].png
% ipple\greyscale\p_x_given_n[426].png
% ipple\greyscale\p_x_given_n[427].png
% ipple\greyscale\p_x_given_n[428].png
% ipple\greyscale\p_x_given_n[429].png
% ipple\greyscale\p_x_given_n[42].png
% ipple\greyscale\p_x_given_n[430].png
% ipple\greyscale\p_x_given_n[431].png
% ipple\greyscale\p_x_given_n[432].png
% ipple\greyscale\p_x_given_n[433].png
% ipple\greyscale\p_x_given_n[434].png
% ipple\greyscale\p_x_given_n[435].png
% ipple\greyscale\p_x_given_n[436].png
% ipple\greyscale\p_x_given_n[437].png
% ipple\greyscale\p_x_given_n[438].png
% ipple\greyscale\p_x_given_n[439].png
% ipple\greyscale\p_x_given_n[43].png
% ipple\greyscale\p_x_given_n[440].png
% ipple\greyscale\p_x_given_n[441].png
% ipple\greyscale\p_x_given_n[442].png
% ipple\greyscale\p_x_given_n[443].png
% ipple\greyscale\p_x_given_n[444].png
% ipple\greyscale\p_x_given_n[445].png
% ipple\greyscale\p_x_given_n[446].png
% ipple\greyscale\p_x_given_n[447].png
% ipple\greyscale\p_x_given_n[448].png
% ipple\greyscale\p_x_given_n[449].png
% ipple\greyscale\p_x_given_n[44].png
% ipple\greyscale\p_x_given_n[450].png
% ipple\greyscale\p_x_given_n[451].png
% ipple\greyscale\p_x_given_n[452].png
% ipple\greyscale\p_x_given_n[453].png
% ipple\greyscale\p_x_given_n[454].png
% ipple\greyscale\p_x_given_n[455].png
% ipple\greyscale\p_x_given_n[456].png
% ipple\greyscale\p_x_given_n[457].png
% ipple\greyscale\p_x_given_n[458].png
% ipple\greyscale\p_x_given_n[459].png
% ipple\greyscale\p_x_given_n[45].png
% ipple\greyscale\p_x_given_n[460].png
% ipple\greyscale\p_x_given_n[461].png
% ipple\greyscale\p_x_given_n[462].png
% ipple\greyscale\p_x_given_n[463].png
% ipple\greyscale\p_x_given_n[464].png
% ipple\greyscale\p_x_given_n[465].png
% ipple\greyscale\p_x_given_n[466].png
% ipple\greyscale\p_x_given_n[467].png
% ipple\greyscale\p_x_given_n[468].png
% ipple\greyscale\p_x_given_n[469].png
% ipple\greyscale\p_x_given_n[46].png
% ipple\greyscale\p_x_given_n[470].png
% ipple\greyscale\p_x_given_n[471].png
% ipple\greyscale\p_x_given_n[472].png
% ipple\greyscale\p_x_given_n[473].png
% ipple\greyscale\p_x_given_n[474].png
% ipple\greyscale\p_x_given_n[475].png
% ipple\greyscale\p_x_given_n[476].png
% ipple\greyscale\p_x_given_n[477].png
% ipple\greyscale\p_x_given_n[478].png
% ipple\greyscale\p_x_given_n[479].png
% ipple\greyscale\p_x_given_n[47].png
% ipple\greyscale\p_x_given_n[480].png
% ipple\greyscale\p_x_given_n[481].png
% ipple\greyscale\p_x_given_n[482].png
% ipple\greyscale\p_x_given_n[483].png
% ipple\greyscale\p_x_given_n[484].png
% ipple\greyscale\p_x_given_n[485].png
% ipple\greyscale\p_x_given_n[486].png
% ipple\greyscale\p_x_given_n[487].png
% ipple\greyscale\p_x_given_n[488].png
% ipple\greyscale\p_x_given_n[489].png
% ipple\greyscale\p_x_given_n[48].png
% ipple\greyscale\p_x_given_n[490].png
% ipple\greyscale\p_x_given_n[491].png
% ipple\greyscale\p_x_given_n[492].png
% ipple\greyscale\p_x_given_n[493].png
% ipple\greyscale\p_x_given_n[494].png
% ipple\greyscale\p_x_given_n[495].png
% ipple\greyscale\p_x_given_n[496].png
% ipple\greyscale\p_x_given_n[497].png
% ipple\greyscale\p_x_given_n[498].png
% ipple\greyscale\p_x_given_n[499].png
% ipple\greyscale\p_x_given_n[49].png
% ipple\greyscale\p_x_given_n[4].png
% ipple\greyscale\p_x_given_n[500].png
% ipple\greyscale\p_x_given_n[501].png
% ipple\greyscale\p_x_given_n[502].png
% ipple\greyscale\p_x_given_n[503].png
% ipple\greyscale\p_x_given_n[504].png
% ipple\greyscale\p_x_given_n[505].png
% ipple\greyscale\p_x_given_n[506].png
% ipple\greyscale\p_x_given_n[507].png
% ipple\greyscale\p_x_given_n[508].png
% ipple\greyscale\p_x_given_n[509].png
% ipple\greyscale\p_x_given_n[50].png
% ipple\greyscale\p_x_given_n[510].png
% ipple\greyscale\p_x_given_n[511].png
% ipple\greyscale\p_x_given_n[512].png
% ipple\greyscale\p_x_given_n[513].png
% ipple\greyscale\p_x_given_n[514].png
% ipple\greyscale\p_x_given_n[515].png
% ipple\greyscale\p_x_given_n[516].png
% ipple\greyscale\p_x_given_n[517].png
% ipple\greyscale\p_x_given_n[518].png
% ipple\greyscale\p_x_given_n[519].png
% ipple\greyscale\p_x_given_n[51].png
% ipple\greyscale\p_x_given_n[520].png
% ipple\greyscale\p_x_given_n[521].png
% ipple\greyscale\p_x_given_n[522].png
% ipple\greyscale\p_x_given_n[523].png
% ipple\greyscale\p_x_given_n[524].png
% ipple\greyscale\p_x_given_n[525].png
% ipple\greyscale\p_x_given_n[526].png
% ipple\greyscale\p_x_given_n[527].png
% ipple\greyscale\p_x_given_n[528].png
% ipple\greyscale\p_x_given_n[529].png
% ipple\greyscale\p_x_given_n[52].png
% ipple\greyscale\p_x_given_n[530].png
% ipple\greyscale\p_x_given_n[531].png
% ipple\greyscale\p_x_given_n[532].png
% ipple\greyscale\p_x_given_n[533].png
% ipple\greyscale\p_x_given_n[534].png
% ipple\greyscale\p_x_given_n[535].png
% ipple\greyscale\p_x_given_n[536].png
% ipple\greyscale\p_x_given_n[537].png
% ipple\greyscale\p_x_given_n[538].png
% ipple\greyscale\p_x_given_n[539].png
% ipple\greyscale\p_x_given_n[53].png
% ipple\greyscale\p_x_given_n[540].png
% ipple\greyscale\p_x_given_n[541].png
% ipple\greyscale\p_x_given_n[542].png
% ipple\greyscale\p_x_given_n[543].png
% ipple\greyscale\p_x_given_n[544].png
% ipple\greyscale\p_x_given_n[545].png
% ipple\greyscale\p_x_given_n[546].png
% ipple\greyscale\p_x_given_n[547].png
% ipple\greyscale\p_x_given_n[548].png
% ipple\greyscale\p_x_given_n[549].png
% ipple\greyscale\p_x_given_n[54].png
% ipple\greyscale\p_x_given_n[550].png
% ipple\greyscale\p_x_given_n[551].png
% ipple\greyscale\p_x_given_n[552].png
% ipple\greyscale\p_x_given_n[553].png
% ipple\greyscale\p_x_given_n[554].png
% ipple\greyscale\p_x_given_n[555].png
% ipple\greyscale\p_x_given_n[556].png
% ipple\greyscale\p_x_given_n[557].png
% ipple\greyscale\p_x_given_n[558].png
% ipple\greyscale\p_x_given_n[559].png
% ipple\greyscale\p_x_given_n[55].png
% ipple\greyscale\p_x_given_n[560].png
% ipple\greyscale\p_x_given_n[561].png
% ipple\greyscale\p_x_given_n[562].png
% ipple\greyscale\p_x_given_n[563].png
% ipple\greyscale\p_x_given_n[564].png
% ipple\greyscale\p_x_given_n[565].png
% ipple\greyscale\p_x_given_n[566].png
% ipple\greyscale\p_x_given_n[567].png
% ipple\greyscale\p_x_given_n[568].png
% ipple\greyscale\p_x_given_n[569].png
% ipple\greyscale\p_x_given_n[56].png
% ipple\greyscale\p_x_given_n[570].png
% ipple\greyscale\p_x_given_n[571].png
% ipple\greyscale\p_x_given_n[572].png
% ipple\greyscale\p_x_given_n[573].png
% ipple\greyscale\p_x_given_n[574].png
% ipple\greyscale\p_x_given_n[575].png
% ipple\greyscale\p_x_given_n[576].png
% ipple\greyscale\p_x_given_n[577].png
% ipple\greyscale\p_x_given_n[578].png
% ipple\greyscale\p_x_given_n[579].png
% ipple\greyscale\p_x_given_n[57].png
% ipple\greyscale\p_x_given_n[580].png
% ipple\greyscale\p_x_given_n[581].png
% ipple\greyscale\p_x_given_n[582].png
% ipple\greyscale\p_x_given_n[583].png
% ipple\greyscale\p_x_given_n[584].png
% ipple\greyscale\p_x_given_n[585].png
% ipple\greyscale\p_x_given_n[586].png
% ipple\greyscale\p_x_given_n[587].png
% ipple\greyscale\p_x_given_n[588].png
% ipple\greyscale\p_x_given_n[589].png
% ipple\greyscale\p_x_given_n[58].png
% ipple\greyscale\p_x_given_n[590].png
% ipple\greyscale\p_x_given_n[591].png
% ipple\greyscale\p_x_given_n[592].png
% ipple\greyscale\p_x_given_n[593].png
% ipple\greyscale\p_x_given_n[594].png
% ipple\greyscale\p_x_given_n[595].png
% ipple\greyscale\p_x_given_n[596].png
% ipple\greyscale\p_x_given_n[597].png
% ipple\greyscale\p_x_given_n[598].png
% ipple\greyscale\p_x_given_n[599].png
% ipple\greyscale\p_x_given_n[59].png
% ipple\greyscale\p_x_given_n[5].png
% ipple\greyscale\p_x_given_n[600].png
% ipple\greyscale\p_x_given_n[601].png
% ipple\greyscale\p_x_given_n[602].png
% ipple\greyscale\p_x_given_n[603].png
% ipple\greyscale\p_x_given_n[604].png
% ipple\greyscale\p_x_given_n[605].png
% ipple\greyscale\p_x_given_n[606].png
% ipple\greyscale\p_x_given_n[607].png
% ipple\greyscale\p_x_given_n[608].png
% ipple\greyscale\p_x_given_n[609].png
% ipple\greyscale\p_x_given_n[60].png
% ipple\greyscale\p_x_given_n[610].png
% ipple\greyscale\p_x_given_n[61].png
% ipple\greyscale\p_x_given_n[62].png
% ipple\greyscale\p_x_given_n[63].png
% ipple\greyscale\p_x_given_n[64].png
% ipple\greyscale\p_x_given_n[65].png
% ipple\greyscale\p_x_given_n[66].png
% ipple\greyscale\p_x_given_n[67].png
% ipple\greyscale\p_x_given_n[68].png
% ipple\greyscale\p_x_given_n[69].png
% ipple\greyscale\p_x_given_n[6].png
% ipple\greyscale\p_x_given_n[70].png
% ipple\greyscale\p_x_given_n[71].png
% ipple\greyscale\p_x_given_n[72].png
% ipple\greyscale\p_x_given_n[73].png
% ipple\greyscale\p_x_given_n[74].png
% ipple\greyscale\p_x_given_n[75].png
% ipple\greyscale\p_x_given_n[76].png
% ipple\greyscale\p_x_given_n[77].png
% ipple\greyscale\p_x_given_n[78].png
% ipple\greyscale\p_x_given_n[79].png
% ipple\greyscale\p_x_given_n[7].png
% ipple\greyscale\p_x_given_n[80].png
% ipple\greyscale\p_x_given_n[81].png
% ipple\greyscale\p_x_given_n[82].png
% ipple\greyscale\p_x_given_n[83].png
% ipple\greyscale\p_x_given_n[84].png
% ipple\greyscale\p_x_given_n[85].png
% ipple\greyscale\p_x_given_n[86].png
% ipple\greyscale\p_x_given_n[87].png
% ipple\greyscale\p_x_given_n[88].png
% ipple\greyscale\p_x_given_n[89].png
% ipple\greyscale\p_x_given_n[8].png
% ipple\greyscale\p_x_given_n[90].png
% ipple\greyscale\p_x_given_n[91].png
% ipple\greyscale\p_x_given_n[92].png
% ipple\greyscale\p_x_given_n[93].png
% ipple\greyscale\p_x_given_n[94].png
% ipple\greyscale\p_x_given_n[95].png
% ipple\greyscale\p_x_given_n[96].png
% ipple\greyscale\p_x_given_n[97].png
% ipple\greyscale\p_x_given_n[98].png
% ipple\greyscale\p_x_given_n[99].png
% ipple\greyscale\p_x_given_n[9].png

% %% [markdown]
% ## Image Processing Interactive

% %%
epoch_idx =7
% Out:
% epoch_idx =
%      7

% %%
%im = processed_images.seg_bw{epoch_idx};
%info = processed_images.info{epoch_idx};
im = processed_images.imgray{epoch_idx};
% a_shape = size(im)
%
% lap_sizes = [1024, 449]
% ripple_sizes = [1024, 143]
%
% lap_to_ripple_size_ratio = ripple_sizes ./ lap_sizes
%
% % Laps:
% parameters.radius = 4;
% parameters.decomposition = 6;
% parameters.sigma = 59; % You can adjust the sigma value
% % parameters.sigma = [10, 59]; % You can adjust the sigma value
%
% % Ripples:
% %parameters.radius = 4;
% %parameters.decomposition = 6;
% %parameters.sigma = 59; % You can adjust the sigma value
% % sigma = [10, 59]; % You can adjust the sigma value
%
%
% ex_lap_sizes = [1024, 449];
% ex_ripple_sizes = [1024, 143];
%
% ex_lap_to_ripple_size_ratio = ex_ripple_sizes ./ ex_lap_sizes;
% %ex_lap_to_ripple_size_ratio = [1.0000,    0.3185]
% lap_to_ripple_size_ratio = ex_lap_to_ripple_size_ratio .* a_shape
%
%
% % Ripples:
% parameters.radius = round(parameters.radius * min(lap_to_ripple_size_ratio));
% %parameters.decomposition = round(parameters.decomposition * min(lap_to_ripple_size_ratio));
% parameters.sigma = parameters.sigma * min(lap_to_ripple_size_ratio);
% %parameters.sigma = round(parameters.sigma * min(lap_to_ripple_size_ratio));
% parameters
%
% [processed_images.seg_bw{epoch_idx}, processed_images.seg_maskedImage{epoch_idx}, processed_images.blurredImg{epoch_idx}] = fn_segimg_replay_connect(im, parameters.sigma, parameters.radius, parameters.decomposition);

bw = processed_images.seg_bw{epoch_idx};
blurredImg = processed_images.blurredImg{epoch_idx};
BW = processed_images.seg_bw{epoch_idx};
maskedImage = processed_images.seg_maskedImage{epoch_idx};
E = processed_images.E(epoch_idx,1);
%processed_images = mergevars(processed_images, {'l','m00','m01','m02','m10','m11','m20'}, 'NewVariableName', 'l_m00_m01_m02_m10_m11_m20', 'MergeAsTable', false);
l = processed_images.l(epoch_idx);
m00 = processed_images.m00(epoch_idx);
m01 = processed_images.m01(epoch_idx);
m02 = processed_images.m02(epoch_idx);
m10 = processed_images.m10(epoch_idx);
m11 = processed_images.m11(epoch_idx);
m20 = processed_images.m20(epoch_idx);
w = processed_images.w(epoch_idx);
x = processed_images.x(epoch_idx);
x1 = processed_images.x1(epoch_idx);
x2 = processed_images.x2(epoch_idx);
y = processed_images.y(epoch_idx);
y1 = processed_images.y1(epoch_idx);
y2 = processed_images.y2(epoch_idx);
theta = processed_images.theta(epoch_idx);

%[BW, blurredImg, maskedImage] = fn_segimg_replay_connect(im);

figure(1); imshow(im);
% Out:
% <center><img src="data:image/png;base64,..." width="178" alt="figure_0.png"></center>

% %%
figure(2); imshow(blurredImg);
% Out:
% <center><img src="data:image/png;base64,..." width="178" alt="figure_1.png"></center>

% %%
%figure(3); imshow(bw);
figure(3); imshow(BW);
% Out:
% <center><img src="data:image/png;base64,..." width="178" alt="figure_2.png"></center>

% %%
%figure; imshow(maskedImage);

% imP = ImToPolar(im, 0.6, 1, 40, 200);
% figure(2); imshow(imP);
% imR = PolarToIm(imP, 0.6, 1, 250, 250);
% figure(3); imshow(imR);
% rMin = 0.25; rMax = 0.8;

% Rotation invariant image moments
%moment(im)
inv_moments = Hu_Moments(blurredImg)
% Out:
% inv_moments = 1x7 uint8 row vector
%     18   255   255   255   255   255     0

% %%
%eta = SI_Moment(blurredImg, BW)
%cen_mmt = Centr_Moment(blurredImg, BW, 1, 1)
%F = IMOMENTS(im)

% https://raphael.candelier.fr/?blog=Image%20Moments

%E = IM.get_ellipse(BW)                % Compute the equivalent ellipse
% Draw the ellipse overlaying the image:
figure; imshow(BW)
hold on
IM.draw_ellipse(E, 'elements', {'ellipse','major','minor','semimajor','direction'}) % , 'color', 'm'
% Out:
% <center><img src="data:image/png;base64,..." width="178" alt="figure_3.png"></center>

% %%
% expand the .E struct for each row of the table
% E_stack = [];
% for i = 1:size(processed_images, 1)
%     E = processed_images.E(i,1);
%     %processed_images
%     E_stack = [E_stack; struct2table(E)];
% end

baseNames = processed_images.baseName;
% Use regexp to extract numbers within brackets
epoch_idx = regexp(baseNames, '[(\d+)]', 'tokens');

% Convert extracted cell array of tokens to numeric array
epoch_idx = cellfun(@(x) str2double(x{1}), epoch_idx)
% Out:
% epoch_idx = 611x1
%      0
%    100
%    101
%    102
%    103
%    104
%    105
%    106
%    107
%    108

% %%
processed_images.epoch_idx = epoch_idx;

% %%
function displayProcessedImagesUI(processed_images)
    row_height = 125;
    col_width = 150;
    % Create a uifigure
    fig = uifigure('Name', 'Processed Images and Data', 'Position', [100 100 600 2200]);

    % Create a main scrollable panel
    scrollPanel = uipanel(fig, 'Scrollable', 'on', 'Position', [20 20 560 2260]);

    % Create a grid layout within the panel
    %grid = uigridlayout(scrollPanel, [height(processed_images), 2], 'ColumnWidth', {200, '1x'}, 'RowHeight', repmat({'fit'}, 1, height(processed_images)));
    %grid = uigridlayout(scrollPanel, [height(processed_images), 2], 'ColumnWidth', {col_width, '1x'}, 'RowHeight', repmat([row_height], 1, height(processed_images)));
    grid = uigridlayout(scrollPanel, [height(processed_images), 3], 'ColumnWidth', {col_width, '1x', '1x'}, 'RowHeight', repmat([row_height], 1, height(processed_images)));


    grid.Padding = [5 5 5 5];
    grid.RowSpacing = 10;
    grid.ColumnSpacing = 10;

    % Populate the grid with images and corresponding data
    for i = 1:height(processed_images)
        % Display the image
        img = processed_images.seg_maskedImage{i};
        [imgHeight, imgWidth, ~] = size(img);
        aspectRatio = imgWidth / imgHeight;

        ax = uiaxes(grid);
        ax.Layout.Row = i;
        ax.Layout.Column = 1;

        % Constrain the axes to prevent expansion
        ax.PositionConstraint = 'innerposition';
        ax.XTick = [];
        ax.YTick = [];
        ax.Box = 'on';

        % Display the image and adjust the axis size to fit the fixed width
        fixedWidth = col_width; % Fixed width for the image column
        adjustedHeight = fixedWidth / aspectRatio; % Adjust height based on the image aspect ratio
        %ax.Position(3) = fixedWidth; % Apply fixed width
        %ax.Position(4) = adjustedHeight; % Apply adjusted height
        imshow(img, 'Parent', ax);

        % Display the corresponding numeric data
        dataStr = sprintf('m00: %.2f\nm01: %.2f\nm02: %.2f\nm10: %.2f\nm11: %.2f\nm20: %.2f', ...
            processed_images.m00(i), processed_images.m01(i), processed_images.m02(i), processed_images.m10(i), processed_images.m11(i), processed_images.m20(i));
        uitext = uitextarea(grid, 'Value', dataStr, 'Editable', 'off');
        uitext.Layout.Row = i;
        uitext.Layout.Column = 2;
        uitext.FontSize = 10;

        % Display the additional numeric data (second column)
        dataStr2 = sprintf('x: %.2f\ny: %.2f\ntheta: %.2f\nw: %.2f\nl: %.2f\nx1: %.2f\ny1: %.2f\nx2: %.2f\ny2: %.2f', ...
            processed_images.x(i), processed_images.y(i), processed_images.theta(i), processed_images.w(i), processed_images.l(i), ...
            processed_images.x1(i), processed_images.y1(i), processed_images.x2(i), processed_images.y2(i));
        uitext2 = uitextarea(grid, 'Value', dataStr2, 'Editable', 'off');
        uitext2.Layout.Row = i;
        uitext2.Layout.Column = 3;
        uitext2.FontSize = 10;

    end

    % Adjust the figure to allow resizing
    %fig.SizeChangedFcn = @(src, event) adjustLayout(grid, processed_images);
end

% function adjustLayout(grid, processed_images)
%     % Enforce consistent layout during window resizing
%     for i = 1:height(processed_images)
%         ax = grid.Children(2 * (height(processed_images) - i) + 1); % Get the corresponding axis for each image
%         img = processed_images.seg_maskedImage{i};
%         [imgHeight, imgWidth, ~] = size(img);
%         aspectRatio = imgWidth / imgHeight;
%         fixedWidth = 200; % Re-apply fixed width
%         adjustedHeight = fixedWidth / aspectRatio; % Recalculate height based on aspect ratio
%         ax.Position(3) = fixedWidth;
%         ax.Position(4) = adjustedHeight;
%     end
% end


% Assuming you have a table named processed_images
displayProcessedImagesUI(processed_images);

% %% [markdown]
% ### Post\-hoc Processing of processed\_images

% %%
D = bwdist(~bw);
figure(); imshow(D,[])
title('Distance Transform of Binary Image')

D = -D;
figure(); imshow(D,[])
title('Complement of Distance Transform')

L = watershed(D);
L(~bw) = 0;
rgb = label2rgb(L,'jet',[.5 .5 .5]);
imshow(rgb)
title('Watershed Transform')

% %%
% Read the sample image in
im = imgray{1}; % imread('shapessm.jpg');
im

% %%
% Find edges using the Canny operator with hysteresis thresholds of 0.1
% and 0.2 with smoothing parameter sigma set to 1.
edgeim = edge(im,'canny', [0.1 0.2], 1);

figure(1), imshow(edgeim);

% %%
% Link edge pixels together into lists of sequential edge points, one
% list for each edge contour. A contour/edgelist starts/stops at an
% ending or a junction with another contour/edgelist.
% Here we discard contours less than 10 pixels long.

[edgelist, labelededgeim] = edgelink(edgeim, 10);

% Display the edgelists with random colours for each distinct edge
% in figure 2

drawedgelist(edgelist, size(im), 1, 'rand', 2); axis off

% %%
% Fit line segments to the edgelists
tol = 2;         % Line segments are fitted with maximum deviation from
         % original edge of 2 pixels.
seglist = lineseg(edgelist, tol);

% Draw the fitted line segments stored in seglist in figure window 3 with
% a linewidth of 2 and random colours
drawedgelist(seglist, size(im), 2, 'rand', 3); axis off

% %%
S = fastradial(im, [1 3 5], 2, 0)

% %% [markdown]
% \# Mean square displacement analysis of particle trajectories

% %%
% ma = msdanalyzer(2, 'µm', 's')

% %% [markdown]
% \# Tracking

% %%
% SPACE_UNITS = 'µm';
% TIME_UNITS = 's';
%
% N_PARTICLES = 1;
% N_TIME_STEPS = 1861;
% %N_DIM = 2; % 2D
% N_DIM = 1; % 1D
%
% % Typical values taken from studies of proteins diffusing in membranes:
% % Diffusion coefficient
% D  = 1e-3; % µm^2/s
% % Time step between acquisition; fast acquisition!
% dT = 0.05; % s,
%
% % Area size, just used to disperse particles in 2D. Has no impact on
% % analysis.
% SIZE = 2; % µm
% k = sqrt(2 * D * dT);

% %%
% tracks = cell(N_PARTICLES, 1);
%
% for i = 1 : N_PARTICLES
%
%     % Time
%     time = (0 : N_TIME_STEPS-1)' * dT;
%
%     % Initial position
%     X0 = SIZE .* rand(1, N_DIM);
%
%     % Integrate uncorrelated displacement
%     dX = k * randn(N_TIME_STEPS, N_DIM);
%     dX(1, :) = X0;
%     X = cumsum(dX, 1);
%
%     size(time)
%     size(X)
%     % Store
%     tracks{i} = [time X];
%
% end
% clear i X dX time X0

% %%
% tracks = cell(N_PARTICLES, 1);
% tracks{1} = flat_tracks;

% %%
% ma = msdanalyzer(N_DIM, SPACE_UNITS, TIME_UNITS);
% % This does not work:
% %ma.addAll(tracks);
%
% % This works:
% ma = ma.addAll(tracks);
%
% % Indeed:
% disp(ma)
