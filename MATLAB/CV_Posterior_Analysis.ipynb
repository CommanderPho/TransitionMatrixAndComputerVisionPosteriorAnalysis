% %% [markdown]
% # <span style="color:rgb(213,80,0)">\# 2024\-08\-20 \- Computer Vision (CV) Posterior Analyses </span>

% %%
addpath(genpath('helpers'));
addpath('External'); % Not recur

should_use_parallel = true;
%should_use_parallel = false;

img_path = fullfile("C:\Users\pho\repos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale");
%img_path = fullfile("/home/halechr/Desktop/_temp_individual_posteriors/2024-08-21/laps/greyscale");
img_path
% Out:
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale"

% %%
imdsTrain = imageDatastore(img_path,'IncludeSubfolders',true);
%imdsTrain.readall("UseParallel", should_use_parallel)
% Out:
% $\begin{array} {|c|c|}\hline\text{ } & \text{1} \\ \hline\text{1} & \text{1024x1185 uint8} \\ \hline\text{2} & \text{1024x5209 uint8} \\ \hline\text{3} & \text{1024x3844 uint8} \\ \hline\text{4} & \text{1024x4814 uint8} \\ \hline\text{5} & \text{1024x4634 uint8} \\ \hline\text{6} & \text{1024x5048 uint8} \\ \hline\text{7} & \text{1024x3341 uint8} \\ \hline\text{8} & \text{1024x5245 uint8} \\ \hline\text{9} & \text{1024x6413 uint8} \\ \hline\text{10} & \text{1024x4060 uint8} \\ \hline\text{11} & \text{1024x4473 uint8} \\ \hline\text{12} & \text{1024x1832 uint8} \\ \hline\text{13} & \text{1024x4401 uint8} \\ \hline\text{14} & \text{1024x3269 uint8} \\ \hline\end{array}$

% %%
processed_images = batchposterior_batch_import_imfcn(imdsTrain);
% Out:
% Starting parallel pool (parpool) using the 'Processes' profile ...
% Connected to parallel pool with 8 workers.
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[0].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[31].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[35].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[20].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[13].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[24].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[10].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[28].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[17].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[32].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[21].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[29].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[36].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[25].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[14].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[11].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[18].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[33].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[22].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[37].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[15].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[26].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[2].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[12].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[34].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[23].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[38].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[19].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[16].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[30].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[27].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[1].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[59].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[39].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[53].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[56].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[4].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[42].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[46].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[5].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[54].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[57].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[61].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[43].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[47].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[3].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[55].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[60].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[58].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[48].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[50].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[62].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[67].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[44].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[78].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[51].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[40].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[80].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[63].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[49].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[81].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[45].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[68].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[79].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[52].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[83].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[69].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[72].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[41].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[64].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[82].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[73].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[75].png

% %%
%

% %%
imageBatchProcessor(imdsTrain) % shows the GUI

% %%
processed_images = batchposterior_batch_import_imfcn(imdsTrain);
% Out:
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[0].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[10].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[11].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[12].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[13].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[14].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[15].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[16].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[17].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[18].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[19].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[1].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[20].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[21].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[22].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[23].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[24].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[25].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[26].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[27].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[28].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[29].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[2].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[30].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[31].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[32].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[33].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[34].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[35].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[36].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[37].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[38].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[39].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[3].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[40].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[41].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[42].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[43].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[44].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[45].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[46].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[47].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[48].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[49].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[4].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[50].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[51].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[52].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[53].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[54].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[55].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[56].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[57].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[58].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[59].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[5].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[60].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[61].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[62].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[63].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[64].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[65].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[66].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[67].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[68].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[69].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[6].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[70].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[71].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[72].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[73].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[74].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[75].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[76].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[77].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[78].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[79].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[7].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[80].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[81].png
% epos\Spike3DWorkEnv\Spike3D\output_temp_individual_posteriors\2024-08-21\laps\greyscale\p_x_given_n[82].png

% %% [markdown]
% ## Image Processing Interactive

% %%
epoch_idx =15
% Out:
% epoch_idx = 15

% %%
%im = processed_images.seg_bw{epoch_idx};
im = processed_images.imgray{epoch_idx};
bw = processed_images.seg_bw{epoch_idx};
blurredImg = processed_images.blurredImg{epoch_idx};
BW = processed_images.seg_bw{epoch_idx};
maskedImage = processed_images.seg_maskedImage{epoch_idx};
E = processed_images.E(epoch_idx,1);
%processed_images = mergevars(processed_images, {'l','m00','m01','m02','m10','m11','m20'}, 'NewVariableName', 'l_m00_m01_m02_m10_m11_m20', 'MergeAsTable', false);
l = processed_images.l(epoch_idx);
m00 = processed_images.m00(epoch_idx);
m01 = processed_images.m01(epoch_idx);
m02 = processed_images.m02(epoch_idx);
m10 = processed_images.m10(epoch_idx);
m11 = processed_images.m11(epoch_idx);
m20 = processed_images.m20(epoch_idx);
w = processed_images.w(epoch_idx);
x = processed_images.x(epoch_idx);
x1 = processed_images.x1(epoch_idx);
x2 = processed_images.x2(epoch_idx);
y = processed_images.y(epoch_idx);
y1 = processed_images.y1(epoch_idx);
y2 = processed_images.y2(epoch_idx);
theta = processed_images.theta(epoch_idx);

%[BW, blurredImg, maskedImage] = fn_segimg_replay_connect(im);

figure(1); imshow(im);
% Out:
% <center><img src="data:image/png;base64,..." width="1177" alt="figure_0.png"></center>

% %%
figure(2); imshow(blurredImg);
% Out:
% <center><img src="data:image/png;base64,..." width="1177" alt="figure_1.png"></center>

% %%
%figure(3); imshow(bw);
figure(3); imshow(BW);
% Out:
% <center><img src="data:image/png;base64,..." width="1177" alt="figure_2.png"></center>

% %%
%figure; imshow(maskedImage);

% imP = ImToPolar(im, 0.6, 1, 40, 200);
% figure(2); imshow(imP);
% imR = PolarToIm(imP, 0.6, 1, 250, 250);
% figure(3); imshow(imR);
% rMin = 0.25; rMax = 0.8;

% Rotation invariant image moments
%moment(im)
inv_moments = Hu_Moments(blurredImg)
% Out:
% inv_moments = 1x7 uint8 row vector
%    146   255   255   255     0   255   255

% %%
%eta = SI_Moment(blurredImg, BW)
%cen_mmt = Centr_Moment(blurredImg, BW, 1, 1)
%F = IMOMENTS(im)

% https://raphael.candelier.fr/?blog=Image%20Moments

%E = IM.get_ellipse(BW)                % Compute the equivalent ellipse
% Draw the ellipse overlaying the image:
figure; imshow(BW)
hold on
IM.draw_ellipse(E, 'elements', {'ellipse','major','minor','semimajor','direction'}) % , 'color', 'm'
% Out:
% <center><img src="data:image/png;base64,..." width="1177" alt="figure_3.png"></center>

% %%
% expand the .E struct for each row of the table
E_stack = [];
for i = 1:size(processed_images, 1)
    E = processed_images.E(i,1);
    %processed_images
    E_stack = [E_stack; struct2table(E)];
end

processed_images = [processed_images, E_stack];
processed_images
% Out:
% $\begin{array} {|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|c|}\hline\text{ } & \text{E} & \text{blurredImg} & \text{bw} & \text{imgray} & \text{seg_bw} & \text{seg_maskedImage} & \text{fileName} & \text{m00} & \text{m10} & \text{m01} & \text{m11} & \text{m02} & \text{m20} & \text{x} & \text{y} & \text{theta} & \text{w} & \text{l} & \text{x1} & \text{y1} & \text{x2} & \text{y2} \\ \hline\text{1} & \text{1x1 struct} & \text{1024x4060 uint8} & \text{1024x4060 logical} & \text{1024x4060 uint8} & \text{1024x4060 logical} & \text{1024x4060 uint8} & \text{'C:\\Users\\pho\\repos\\Spike3DWorkEnv\\Spike3D\\output\\_temp_individual_posteriors\\2024-08-21\\laps\\greyscale\\p_x_given_n[18].png'} & \text{927034} & \text{1.9220e+09} & \text{426524815} & \text{5.4689e+11} & \text{2.9357e+11} & \text{5.3036e+12} & \text{2.0733e+03} & \text{460.0962} & \text{-0.2524} & \text{211.0900} & \text{2.4629e+03} & \text{4.4493e+03} & \text{-152.6099} & \text{-302.8257} & \text{1.0728e+03} \\ \hline\text{2} & \text{1x1 struct} & \text{1024x4473 uint8} & \text{1024x4473 logical} & \text{1024x4473 uint8} & \text{1024x4473 logical} & \text{1024x4473 uint8} & \text{'C:\\Users\\pho\\repos\\Spike3DWorkEnv\\Spike3D\\output\\_temp_individual_posteriors\\2024-08-21\\laps\\greyscale\\p_x_given_n[19].png'} & \text{248407} & \text{741581568} & \text{206286996} & \text{6.8945e+11} & \text{1.8782e+11} & \text{2.6342e+12} & \text{2.9853e+03} & \text{830.4395} & \text{0.1748} & \text{237.8677} & \text{2.6416e+03} & \text{5.5762e+03} & \text{1.2880e+03} & \text{394.5261} & \text{372.9130} \\ \hline\text{3} & \text{1x1 struct} & \text{1024x1832 uint8} & \text{1024x1832 logical} & \text{1024x1832 uint8} & \text{1024x1832 logical} & \text{1024x1832 uint8} & \text{'C:\\Users\\pho\\repos\\Spike3DWorkEnv\\Spike3D\\output\\_temp_individual_posteriors\\2024-08-21\\laps\\greyscale\\p_x_given_n[1].png'} & \text{618322} & \text{552329227} & \text{453193360} & \text{4.2345e+11} & \text{3.8898e+11} & \text{6.7077e+11} & \text{893.2712} & \text{732.9407} & \text{0.1498} & \text{591.0659} & \text{1.0797e+03} & \text{1.7867e+03} & \text{867.8183} & \text{-0.1334} & \text{598.0631} \\ \hline\text{4} & \text{1x1 struct} & \text{1024x4401 uint8} & \text{1024x4401 logical} & \text{1024x4401 uint8} & \text{1024x4401 logical} & \text{1024x4401 uint8} & \text{'C:\\Users\\pho\\repos\\Spike3DWorkEnv\\Spike3D\\output\\_temp_individual_posteriors\\2024-08-21\\laps\\greyscale\\p_x_given_n[20].png'} & \text{920958} & \text{2.0031e+09} & \text{579785745} & \text{9.1881e+11} & \text{4.6081e+11} & \text{5.7924e+12} & \text{2.1750e+03} & \text{629.5463} & \text{2.9054} & \text{241.6858} & \text{2.5676e+03} & \text{-310.2558} & \text{1.2277e+03} & \text{4.6603e+03} & \text{31.4391} \\ \hline\text{5} & \text{1x1 struct} & \text{1024x3269 uint8} & \text{1024x3269 logical} & \text{1024x3269 uint8} & \text{1024x3269 logical} & \text{1024x3269 uint8} & \text{'C:\\Users\\pho\\repos\\Spike3DWorkEnv\\Spike3D\\output\\_temp_individual_posteriors\\2024-08-21\\laps\\greyscale\\p_x_given_n[21].png'} & \text{468472} & \text{791570946} & \text{342086279} & \text{6.6091e+11} & \text{2.7574e+11} & \text{1.7190e+12} & \text{1.6897e+03} & \text{730.2171} & \text{0.2181} & \text{254.1984} & \text{1.8478e+03} & \text{3.4765e+03} & \text{1.1263e+03} & \text{-97.1196} & \text{334.1281} \\ \hline\text{6} & \text{1x1 struct} & \text{1024x4113 uint8} & \text{1024x4113 logical} & \text{1024x4113 uint8} & \text{1024x4113 logical} & \text{1024x4113 uint8} & \text{'C:\\Users\\pho\\repos\\Spike3DWorkEnv\\Spike3D\\output\\_temp_individual_posteriors\\2024-08-21\\laps\\greyscale\\p_x_given_n[22].png'} & \text{816999} & \text{1.7472e+09} & \text{438604369} & \text{6.2690e+11} & \text{3.3055e+11} & \text{4.8540e+12} & \text{2.1385e+03} & \text{536.8481} & \text{-0.2733} & \text{196.5516} & \text{2.4287e+03} & \text{4.4694e+03} & \text{-116.5153} & \text{-192.4201} & \text{1.1902e+03} \\ \hline\text{7} & \text{1x1 struct} & \text{1024x ...

% %%
function displayProcessedImagesUI(processed_images)
    row_height = 125;
    col_width = 150;
    % Create a uifigure
    fig = uifigure('Name', 'Processed Images and Data', 'Position', [100 100 600 2200]);

    % Create a main scrollable panel
    scrollPanel = uipanel(fig, 'Scrollable', 'on', 'Position', [20 20 560 2260]);

    % Create a grid layout within the panel
    %grid = uigridlayout(scrollPanel, [height(processed_images), 2], 'ColumnWidth', {200, '1x'}, 'RowHeight', repmat({'fit'}, 1, height(processed_images)));
    %grid = uigridlayout(scrollPanel, [height(processed_images), 2], 'ColumnWidth', {col_width, '1x'}, 'RowHeight', repmat([row_height], 1, height(processed_images)));
    grid = uigridlayout(scrollPanel, [height(processed_images), 3], 'ColumnWidth', {col_width, '1x', '1x'}, 'RowHeight', repmat([row_height], 1, height(processed_images)));


    grid.Padding = [5 5 5 5];
    grid.RowSpacing = 10;
    grid.ColumnSpacing = 10;

    % Populate the grid with images and corresponding data
    for i = 1:height(processed_images)
        % Display the image
        img = processed_images.seg_maskedImage{i};
        [imgHeight, imgWidth, ~] = size(img);
        aspectRatio = imgWidth / imgHeight;

        ax = uiaxes(grid);
        ax.Layout.Row = i;
        ax.Layout.Column = 1;

        % Constrain the axes to prevent expansion
        ax.PositionConstraint = 'innerposition';
        ax.XTick = [];
        ax.YTick = [];
        ax.Box = 'on';

        % Display the image and adjust the axis size to fit the fixed width
        fixedWidth = col_width; % Fixed width for the image column
        adjustedHeight = fixedWidth / aspectRatio; % Adjust height based on the image aspect ratio
        %ax.Position(3) = fixedWidth; % Apply fixed width
        %ax.Position(4) = adjustedHeight; % Apply adjusted height
        imshow(img, 'Parent', ax);

        % Display the corresponding numeric data
        dataStr = sprintf('m00: %.2f\nm01: %.2f\nm02: %.2f\nm10: %.2f\nm11: %.2f\nm20: %.2f', ...
            processed_images.m00(i), processed_images.m01(i), processed_images.m02(i), processed_images.m10(i), processed_images.m11(i), processed_images.m20(i));
        uitext = uitextarea(grid, 'Value', dataStr, 'Editable', 'off');
        uitext.Layout.Row = i;
        uitext.Layout.Column = 2;
        uitext.FontSize = 10;

        % Display the additional numeric data (second column)
        dataStr2 = sprintf('x: %.2f\ny: %.2f\ntheta: %.2f\nw: %.2f\nl: %.2f\nx1: %.2f\ny1: %.2f\nx2: %.2f\ny2: %.2f', ...
            processed_images.x(i), processed_images.y(i), processed_images.theta(i), processed_images.w(i), processed_images.l(i), ...
            processed_images.x1(i), processed_images.y1(i), processed_images.x2(i), processed_images.y2(i));
        uitext2 = uitextarea(grid, 'Value', dataStr2, 'Editable', 'off');
        uitext2.Layout.Row = i;
        uitext2.Layout.Column = 3;
        uitext2.FontSize = 10;

    end

    % Adjust the figure to allow resizing
    %fig.SizeChangedFcn = @(src, event) adjustLayout(grid, processed_images);
end

% function adjustLayout(grid, processed_images)
%     % Enforce consistent layout during window resizing
%     for i = 1:height(processed_images)
%         ax = grid.Children(2 * (height(processed_images) - i) + 1); % Get the corresponding axis for each image
%         img = processed_images.seg_maskedImage{i};
%         [imgHeight, imgWidth, ~] = size(img);
%         aspectRatio = imgWidth / imgHeight;
%         fixedWidth = 200; % Re-apply fixed width
%         adjustedHeight = fixedWidth / aspectRatio; % Recalculate height based on aspect ratio
%         ax.Position(3) = fixedWidth;
%         ax.Position(4) = adjustedHeight;
%     end
% end


% Assuming you have a table named processed_images
displayProcessedImagesUI(processed_images);
% Out:
% <center><img src="data:image/png;base64,..." width="247" alt="figure_4.png"></center>

% %% [markdown]
% ### Post\-hoc Processing of processed\_images

% %%
D = bwdist(~bw);
figure(); imshow(D,[])
title('Distance Transform of Binary Image')
% Out:
% <center><img src="data:image/png;base64,..." width="1177" alt="figure_5.png"></center>

% %%
D = -D;
figure(); imshow(D,[])
title('Complement of Distance Transform')
% Out:
% <center><img src="data:image/png;base64,..." width="1177" alt="figure_6.png"></center>

% %%
L = watershed(D);
L(~bw) = 0;
rgb = label2rgb(L,'jet',[.5 .5 .5]);
imshow(rgb)
title('Watershed Transform')
% Out:
% <center><img src="data:image/png;base64,..." width="1177" alt="figure_7.png"></center>

% %%
% Read the sample image in
im = imgray{1}; % imread('shapessm.jpg');
im

% %%
% Find edges using the Canny operator with hysteresis thresholds of 0.1
% and 0.2 with smoothing parameter sigma set to 1.
edgeim = edge(im,'canny', [0.1 0.2], 1);

figure(1), imshow(edgeim);

% %%
% Link edge pixels together into lists of sequential edge points, one
% list for each edge contour. A contour/edgelist starts/stops at an
% ending or a junction with another contour/edgelist.
% Here we discard contours less than 10 pixels long.

[edgelist, labelededgeim] = edgelink(edgeim, 10);

% Display the edgelists with random colours for each distinct edge
% in figure 2

drawedgelist(edgelist, size(im), 1, 'rand', 2); axis off

% %%
% Fit line segments to the edgelists
tol = 2;         % Line segments are fitted with maximum deviation from
         % original edge of 2 pixels.
seglist = lineseg(edgelist, tol);

% Draw the fitted line segments stored in seglist in figure window 3 with
% a linewidth of 2 and random colours
drawedgelist(seglist, size(im), 2, 'rand', 3); axis off

% %%
S = fastradial(im, [1 3 5], 2, 0)

% %% [markdown]
% \# Mean square displacement analysis of particle trajectories

% %%
% ma = msdanalyzer(2, 'µm', 's')

% %% [markdown]
% \# Tracking

% %%
% SPACE_UNITS = 'µm';
% TIME_UNITS = 's';
%
% N_PARTICLES = 1;
% N_TIME_STEPS = 1861;
% %N_DIM = 2; % 2D
% N_DIM = 1; % 1D
%
% % Typical values taken from studies of proteins diffusing in membranes:
% % Diffusion coefficient
% D  = 1e-3; % µm^2/s
% % Time step between acquisition; fast acquisition!
% dT = 0.05; % s,
%
% % Area size, just used to disperse particles in 2D. Has no impact on
% % analysis.
% SIZE = 2; % µm
% k = sqrt(2 * D * dT);

% %%
% tracks = cell(N_PARTICLES, 1);
%
% for i = 1 : N_PARTICLES
%
%     % Time
%     time = (0 : N_TIME_STEPS-1)' * dT;
%
%     % Initial position
%     X0 = SIZE .* rand(1, N_DIM);
%
%     % Integrate uncorrelated displacement
%     dX = k * randn(N_TIME_STEPS, N_DIM);
%     dX(1, :) = X0;
%     X = cumsum(dX, 1);
%
%     size(time)
%     size(X)
%     % Store
%     tracks{i} = [time X];
%
% end
% clear i X dX time X0

% %%
% tracks = cell(N_PARTICLES, 1);
% tracks{1} = flat_tracks;

% %%
% ma = msdanalyzer(N_DIM, SPACE_UNITS, TIME_UNITS);
% % This does not work:
% %ma.addAll(tracks);
%
% % This works:
% ma = ma.addAll(tracks);
%
% % Indeed:
% disp(ma)
